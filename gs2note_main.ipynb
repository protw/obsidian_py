# %% [markdown]
# ## Конвертування Google Sheets таблиці у Obsidian нотатку

# %%
# @title Вхідні параметри
folders = {
    'base': '/content/drive',
    'vaults_base': '/MyDrive/OBSIDIAN/',
    'code_dir': 'obsidian-py/',
    'vault_dir': 'NECU/'
}

cond = {
    'is_dupl_in_vault': False, # Рекомендовано True, за замовчанням
    'is_dupl_in_table': True,  # Рекомендовано True, за замовчанням
    ## ---- СХОВАТИ ВІД КОРИСТУВАЧА ----
    'not_write_dupl':   False,  # Рекомендовано True, за замовчанням
    'is_clean_writing': False  # За замовчанням True
}

table = 'persons' #@param ['persons', 'teams', 'orgs', 'proj']

# %%
# @title Запуск конвертора
import os

# !cd ~
if not os.path.isdir('obsidian_py'):
  # !git clone --quiet https://github.com/protw/obsidian_py.git > /dev/null
os.chdir('obsidian_py')

import gs2note_main

conv = gs2note_main.run(table, cond=cond, folders=folders)
# Out:
# {'base': '/content/drive', 'vaults_base': '/MyDrive/OBSIDIAN/', 'code_dir': 'obsidian-py/', 'vault_dir': 'NECU/'}
# {'is_dupl_in_vault': False, 'is_dupl_in_table': True, 'not_write_dupl': False, 'is_clean_writing': False}
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-145eef30a31a> in <cell line: 0>()
#       9 import gs2note_main
#      10
# ---> 11 conv = gs2note_main.run(table, cond=cond, folders=folders)
#
# /content/obsidian_py/gs2note_main.py in run(table, folders, cond)
#      34
#      35     # Ініціюємо конвертор. Встановлюємо повні шляхи до фолдерів коду і даних
# ---> 36     conv = GS2ON_Convertor(folders, **cond)
#      37
#      38     # Основоний метод класу `GS2ON_Convertor`
#
# /content/obsidian_py/gs2note.py in __init__(self, folders, is_dupl_in_vault, is_dupl_in_table, not_write_dupl, is_clean_writing)
#      56
#      57         # Створення конфігураційного словника self.conf
# ---> 58         self.read_yaml_config()
#      59
#      60     def check_dupl_in_vault(self):
#
# /content/obsidian_py/gs2note.py in read_yaml_config(self)
#      86         ''' Зчитування конфігураційних словників з файлів і створення
#      87         внутрішнього конфігураційного словника '''
# ---> 88         with open(self.config_file) as f:
#      89             conf = yaml.load(f, Loader=yaml.SafeLoader)
#      90         with open(self.config_gs_file) as f:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/OBSIDIAN/obsidian-py/config.yml'

# %%
conv.config_file
